# %%
# !pip install pandas
# !pip install scipy
# !pip install transformers
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Requirement already satisfied: pandas in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scipy in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from scipy) (1.26.4)
# Requirement already satisfied: transformers in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (4.46.2)
# Requirement already satisfied: filelock in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: pip in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (24.3.1)
# Requirement already satisfied: setuptools in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (75.3.0)
# Requirement already satisfied: wheel in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (0.44.0)
# Requirement already satisfied: spacy in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (75.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: click>=8.0.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Using cached numpy-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 105.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (2.5.1+cpu)
# Requirement already satisfied: torchvision in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (0.20.1+cpu)
# Requirement already satisfied: torchaudio in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (2.5.1+cpu)
# Requirement already satisfied: filelock in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zaki/anaconda3/envs/py311_env/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import re
import spacy
import urllib
import csv

nlp = spacy.load("en_core_web_sm")



MODEL = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

task='sentiment'
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]


def preprocess_text(text):
    """
    Preprocess the input text using the provided spaCy model.

    Args:
        text (str): The input text to preprocess.
        nlp_model: The preloaded spaCy language model.

    Returns:
        str: The preprocessed text.
    """
    # Process the text with the spaCy model
    doc = nlp(text)
    processed_text = doc.text.strip()
    return processed_text

def get_sentiment(text) -> dict:
    try:
        text = str(text)
        text = preprocess_text(text)
    
    
        if len(text) == 0:
            return {
                "positive": 0.0,
                "neutral": 0.0,
                "negative": 0.0
            }
    
        encoded_input = tokenizer(text, return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)

        ranking = np.argsort(scores)
        ranking = ranking[::-1]

        sentiment={}

        for i in range(scores.shape[0]):
            l = labels[ranking[i]]
            s = scores[ranking[i]]
            sentiment[l]=s
        
        return sentiment
        
    except:
        return {
            "positive": 0.0,
            "neutral": 0.0,
            "negative": 0.0
        }

# %%
import pandas as pd
import os
column = "review"

data_folder = "reviews-ubisoft"

def getCSVs(folder) -> list[str]:
    return [f for f in os.listdir(folder) if f.endswith('.csv')]

for file in getCSVs(data_folder):
    print(f"Starting with {data_folder}/{file}")

    df = pd.read_csv(f"{data_folder}/{file}", delimiter=",", on_bad_lines="skip", engine="python")
    
    print(f"Starting with {file}")
    
    df["sentiment"] = df.apply(lambda x: get_sentiment(x[column]), axis=1)
    df["negative"] = df["sentiment"].apply(lambda x: x["negative"])
    df["neutral"] = df["sentiment"].apply(lambda x: x["neutral"])
    df["positive"] = df["sentiment"].apply(lambda x: x["positive"])
    
    df.to_csv(f"{data_folder}/{file}", index=False)
    print(f"Done with {file}")
# Out:
# Starting with reviews-ubisoft/reviews_2290180.csv
# Starting with reviews_2290180.csv
# Done with reviews_2290180.csv
# Starting with reviews-ubisoft/reviews_3035570.csv
# Starting with reviews_3035570.csv
# Done with reviews_3035570.csv
# Starting with reviews-ubisoft/reviews_220240.csv
# Starting with reviews_220240.csv
# Done with reviews_220240.csv
# Starting with reviews-ubisoft/reviews_33230.csv
# Starting with reviews_33230.csv
# Done with reviews_33230.csv
# Starting with reviews-ubisoft/reviews_365590.csv
# Starting with reviews_365590.csv
# Done with reviews_365590.csv
# Starting with reviews-ubisoft/reviews_2231380.csv
# Starting with reviews_2231380.csv
# Done with reviews_2231380.csv
# Starting with reviews-ubisoft/reviews_916440.csv
# Starting with reviews_916440.csv
# Done with reviews_916440.csv
# Starting with reviews-ubisoft/reviews_359550.csv
# Starting with reviews_359550.csv
# Done with reviews_359550.csv
# Starting with reviews-ubisoft/reviews_2751000.csv
# Starting with reviews_2751000.csv
# Done with reviews_2751000.csv
# Starting with reviews-ubisoft/reviews_2698940.csv
# Starting with reviews_2698940.csv
# Done with reviews_2698940.csv
# Starting with reviews-ubisoft/reviews_2228800.csv
# Starting with reviews_2228800.csv
# Done with reviews_2228800.csv
# Starting with reviews-ubisoft/reviews_2369390.csv
# Starting with reviews_2369390.csv
# Done with reviews_2369390.csv
# Starting with reviews-ubisoft/reviews_2842040.csv
# Starting with reviews_2842040.csv
# Done with reviews_2842040.csv
# Starting with reviews-ubisoft/reviews_2208920.csv
# Starting with reviews_2208920.csv
# Done with reviews_2208920.csv
# Starting with reviews-ubisoft/reviews_2853730.csv
# Starting with reviews_2853730.csv
# Done with reviews_2853730.csv
# Starting with reviews-ubisoft/reviews_243470.csv
# Starting with reviews_243470.csv
# Done with reviews_243470.csv
# Starting with reviews-ubisoft/reviews_242550.csv
# Starting with reviews_242550.csv
# Done with reviews_242550.csv
# Starting with reviews-ubisoft/reviews_242050.csv
# Starting with reviews_242050.csv
# Done with reviews_242050.csv
# Starting with reviews-ubisoft/reviews_2379390.csv
# Starting with reviews_2379390.csv
