# %%
# !pip install scipy
# !pip install transformers
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
# Collecting numpy==1.24.3
#   Downloading numpy-1.24.3.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 74.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/home/zaki/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/home/zaki/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/zaki/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 112, in get_requires_for_build_wheel
#           backend = _build_backend()
#                     ^^^^^^^^^^^^^^^^
#         File "/home/zaki/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 77, in _build_backend
#           obj = import_module(mod_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#         File "/home/zaki/anaconda3/lib/python3.12/importlib/__init__.py", line 90, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "/tmp/pip-build-env-_umpewv2/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 16, in <module>
#           import setuptools.version
#         File "/tmp/pip-build-env-_umpewv2/overlay/lib/python3.12/site-packages/setuptools/version.py", line 1, in <module>
#           import pkg_resources
#         File "/tmp/pip-build-env-_umpewv2/overlay/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting blis
#   Downloading blis-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Collecting thinc
#   Downloading thinc-9.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting numpy<3.0.0,>=2.0.0 (from blis)
#   Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting murmurhash<1.1.0,>=1.0.2 (from thinc)
#   Downloading murmurhash-1.0.10-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from thinc)
#   Downloading cymem-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from thinc)
#   Downloading preshed-3.0.9-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting wasabi<1.2.0,>=0.8.1 (from thinc)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.0 (from thinc)
#   Downloading srsly-2.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.4 (from thinc)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting setuptools (from thinc)
#   Using cached setuptools-75.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from thinc)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting packaging>=20.0 (from thinc)
#   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->thinc)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->thinc)
#   Downloading pydantic_core-2.23.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->thinc)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading blis-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 195.2 MB/s eta 0:00:00
# Downloading thinc-9.1.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 132.7 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading cymem-2.0.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
# Downloading murmurhash-1.0.10-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 166.4 MB/s eta 0:00:00
# Downloading packaging-24.1-py3-none-any.whl (53 kB)
# Downloading preshed-3.0.9-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (156 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Downloading pydantic_core-2.23.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 235.8 MB/s eta 0:00:00
# Downloading srsly-2.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (491 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached setuptools-75.3.0-py3-none-any.whl (1.3 MB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: cymem, wasabi, typing-extensions, setuptools, packaging, numpy, murmurhash, catalogue, annotated-types, srsly, pydantic-core, preshed, blis, pydantic, confection, thinc
#   Attempting uninstall: cymem
#     Found existing installation: cymem 2.0.8
#     Uninstalling cymem-2.0.8:
#       Successfully uninstalled cymem-2.0.8
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.3.0
#     Uninstalling setuptools-75.3.0:
#       Successfully uninstalled setuptools-75.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: murmurhash
#     Found existing installation: murmurhash 1.0.10
#     Uninstalling murmurhash-1.0.10:
#       Successfully uninstalled murmurhash-1.0.10
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.10
#     Uninstalling catalogue-2.0.10:
#       Successfully uninstalled catalogue-2.0.10
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
#       Successfully uninstalled srsly-2.4.8
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.23.4
#     Uninstalling pydantic_core-2.23.4:
#       Successfully uninstalled pydantic_core-2.23.4
#   Attempting uninstall: preshed
#     Found existing installation: preshed 3.0.9
#     Uninstalling preshed-3.0.9:
#       Successfully uninstalled preshed-3.0.9
#   Attempting uninstall: blis
#     Found existing installation: blis 1.0.1
#     Uninstalling blis-1.0.1:
#       Successfully uninstalled blis-1.0.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
#   Attempting uninstall: confection
#     Found existing installation: confection 0.1.5
#     Uninstalling confection-0.1.5:
#       Successfully uninstalled confection-0.1.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.3.2
#     Uninstalling thinc-8.3.2:
#       Successfully uninstalled thinc-8.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.8.2 requires thinc<8.4.0,>=8.3.0, but you have thinc 9.1.1 which is incompatible.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.1.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.3 which is incompatible.
# Successfully installed annotated-types-0.7.0 blis-1.0.1 catalogue-2.0.10 confection-0.1.5 cymem-2.0.8 murmurhash-1.0.10 numpy-2.1.3 packaging-24.1 preshed-3.0.9 pydantic-2.9.2 pydantic-core-2.23.4 setuptools-75.3.0 srsly-2.4.8 thinc-9.1.1 typing-extensions-4.12.2 wasabi-1.1.3
# Requirement already satisfied: scipy in /home/zaki/anaconda3/lib/python3.12/site-packages (1.12.0)
# Collecting numpy<1.29.0,>=1.22.4 (from scipy)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.8.2 requires thinc<8.4.0,>=8.3.0, but you have thinc 9.1.1 which is incompatible.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 9.1.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Requirement already satisfied: transformers in /home/zaki/anaconda3/lib/python3.12/site-packages (4.46.2)
# Requirement already satisfied: filelock in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /home/zaki/anaconda3/lib/python3.12/site-packages (from transformers) (4.67.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zaki/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: pip in /home/zaki/anaconda3/lib/python3.12/site-packages (24.3.1)
# Requirement already satisfied: setuptools in /home/zaki/anaconda3/lib/python3.12/site-packages (75.3.0)
# Requirement already satisfied: wheel in /home/zaki/anaconda3/lib/python3.12/site-packages (0.44.0)
# Requirement already satisfied: spacy in /home/zaki/anaconda3/lib/python3.12/site-packages (3.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (3.0.9)
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Downloading thinc-8.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (75.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/zaki/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zaki/anaconda3/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: click>=8.0.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/zaki/anaconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/zaki/anaconda3/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading thinc-8.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 144.8 MB/s eta 0:00:00
# Using cached numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
# Installing collected packages: numpy, thinc
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: thinc
#     Found existing installation: thinc 9.1.1
#     Uninstalling thinc-9.1.1:
#       Successfully uninstalled thinc-9.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.12.0 requires numpy<1.29.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2 thinc-8.3.2
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 211.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /home/zaki/anaconda3/lib/python3.12/site-packages (2.5.1+cpu)
# Requirement already satisfied: torchvision in /home/zaki/anaconda3/lib/python3.12/site-packages (0.20.1+cpu)
# Requirement already satisfied: torchaudio in /home/zaki/anaconda3/lib/python3.12/site-packages (2.5.1+cpu)
# Requirement already satisfied: filelock in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: setuptools in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (75.3.0)
# Requirement already satisfied: sympy==1.13.1 in /home/zaki/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/zaki/anaconda3/lib/python3.12/site-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/zaki/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import re
import spacy
import urllib
import csv

nlp = spacy.load("en_core_web_sm")



MODEL = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

task='sentiment'
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]


def preprocess_text(text):
    """
    Preprocess the input text using the provided spaCy model.

    Args:
        text (str): The input text to preprocess.
        nlp_model: The preloaded spaCy language model.

    Returns:
        str: The preprocessed text.
    """
    # Process the text with the spaCy model
    doc = nlp(text)
    processed_text = doc.text.strip()
    return processed_text

def get_sentiment(text) -> dict:
    try:
        text = str(text)
        text = preprocess_text(text)
    
    
        if len(text) == 0:
            return {
                "positive": 0.0,
                "neutral": 0.0,
                "negative": 0.0
            }
    
        encoded_input = tokenizer(text, return_tensors='pt')
        output = model(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = softmax(scores)

        ranking = np.argsort(scores)
        ranking = ranking[::-1]

        sentiment={}

        for i in range(scores.shape[0]):
            l = labels[ranking[i]]
            s = scores[ranking[i]]
            sentiment[l]=s
        
        return sentiment
        
    except:
        return {
            "positive": 0.0,
            "neutral": 0.0,
            "negative": 0.0
        }

# %%
import pandas as pd
import os
column = "review"

data_folder = "reviews-ubisoft"

def getCSVs(folder) -> list[str]:
    return [f for f in os.listdir(folder) if f.endswith('.csv')]

for file in getCSVs(data_folder):
    print(f"Starting with {data_folder}/{file}")

    df = pd.read_csv(f"{data_folder}/{file}", delimiter=",", on_bad_lines="skip", engine="python")
    
    print(f"Starting with {file}")
    
    df["sentiment"] = df.apply(lambda x: get_sentiment(x[column]), axis=1)
    df["negative"] = df["sentiment"].apply(lambda x: x["negative"])
    df["neutral"] = df["sentiment"].apply(lambda x: x["neutral"])
    df["positive"] = df["sentiment"].apply(lambda x: x["positive"])
    
    df.to_csv(f"{data_folder}/{file}", index=False)
    print(f"Done with {file}")
