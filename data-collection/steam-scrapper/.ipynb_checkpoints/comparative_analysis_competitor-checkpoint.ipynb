# %%
import pandas as pd
import ast
import re
import os
import re
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt

data_folder = "reviews-ubisoft"

def getCSVs(folder) -> list[str]:
    return [f for f in os.listdir(folder) if f.endswith('.csv')]

# Sample function for loading, cleaning, and parsing the sentiment column as before
def clean_and_parse_sentiment(sentiment_str):
    cleaned_str = re.sub(r'np\.float32\(([\d\.]+)\)', r'\1', sentiment_str)
    return ast.literal_eval(cleaned_str)

def is_mostly_numeric(text):
    if not isinstance(text, str):
        return False
    return bool(re.fullmatch(r'[-+]?\d*\.?\d+(?:[eE][-+]?\d+)?', text))

for file in getCSVs(data_folder):
    print(f"Reading with {data_folder}/{file}")
    data = pd.read_csv(f"{data_folder}/{file}", low_memory=False)
    if 'sentiment' not in data.columns:
        print(f"Skipping {file}: 'sentiment' column not found.")
        continue  # Skip this file and move to the next one
        
    # Assuming you have a DataFrame called 'data' with sentiment and review columns
    data = data[~data['review'].apply(is_mostly_numeric)]

    # Convert and parse the 'sentiments' column
    data['sentiments'] = data['sentiment'].apply(lambda x: clean_and_parse_sentiment(x) if isinstance(x, str) else x)

    # Extract individual sentiment scores and add them as separate columns
    data['positive'] = data['sentiments'].apply(lambda x: x.get('positive', 0))
    data['neutral'] = data['sentiments'].apply(lambda x: x.get('neutral', 0))
    data['negative'] = data['sentiments'].apply(lambda x: x.get('negative', 0))

    # Identify high and low sentiment scores
    high_threshold = 0.8  # Threshold for high scores, adjust as needed
    low_threshold = 0.2   # Threshold for low scores, adjust as needed

    # Filter for high scoring reviews (e.g., high positive or high negative)
    high_scoring_reviews = data[(data['positive'] >= high_threshold) | (data['negative'] >= high_threshold)]

    # Filter for low scoring reviews (e.g., low positive and low negative, mostly neutral)
    low_scoring_reviews = data[(data['positive'] <= low_threshold) & (data['negative'] <= low_threshold)]

    # Display the high and low scoring reviews
    high_scoring_styled = high_scoring_reviews[['review', 'positive', 'neutral', 'negative']].head(10).style \
        .set_caption("High Scoring Reviews") \
        .background_gradient(subset=['positive', 'neutral', 'negative'], cmap="Greens") \
        .set_table_styles([
            {'selector': 'caption', 'props': [('color', 'black'), ('font-weight', 'bold')]},
            {'selector': 'table', 'props': [('border', '1px solid black')]}
        ]) \
        .set_properties(**{'text-align': 'left'})
    display(high_scoring_styled)
    
    low_scoring_styled = low_scoring_reviews[['review', 'positive', 'neutral', 'negative']].head(10).style \
        .set_caption("Low Scoring Reviews") \
        .background_gradient(subset=['positive', 'neutral', 'negative'], cmap="Reds") \
        .set_table_styles([
            {'selector': 'caption', 'props': [('color', 'black'), ('font-weight', 'bold')]},
            {'selector': 'table', 'props': [('border', '1px solid black')]}
        ]) \
        .set_properties(**{'text-align': 'left'})
    display(low_scoring_styled)

    # Concatenate all high-scoring reviews and low-scoring reviews into single texts
    high_reviews_text = " ".join(high_scoring_reviews['review'].astype(str))
    low_reviews_text = " ".join(low_scoring_reviews['review'].astype(str))
    
    # Use CountVectorizer to find common words in high and low reviews
    custom_stop_words = list(CountVectorizer(stop_words='english').get_stop_words()) + ['game']

    # Use CountVectorizer to find common words in high and low reviews, excluding "game"
    vectorizer = CountVectorizer(stop_words=custom_stop_words, max_features=10)
    
    # Check if high and low reviews texts contain meaningful content before proceeding
    if high_reviews_text.strip():  # Proceed if high_reviews_text is not empty
        high_counts = vectorizer.fit_transform([high_reviews_text])
        high_common_words = vectorizer.get_feature_names_out()
        high_word_count = high_counts.toarray().flatten()     
        # Create DataFrame for high-scoring words and counts
        high_df = pd.DataFrame({'Word': high_common_words, 'Frequency': high_word_count})
        high_df = high_df.sort_values(by='Frequency', ascending=False)

        # Plot
        plt.figure(figsize=(10, 6))
        plt.barh(high_df['Word'], high_df['Frequency'], color='skyblue')
        plt.xlabel('Frequency')
        plt.title('Top Words in High-Scoring Reviews')
        plt.gca().invert_yaxis()  # Invert to show the most frequent word at the top
        plt.show()
    else:
        print("No significant words in high-scoring reviews after removing stop words.")

    if low_reviews_text.strip():  # Proceed if low_reviews_text is not empty
        low_counts = vectorizer.fit_transform([low_reviews_text])
        low_common_words = vectorizer.get_feature_names_out()
        low_word_count = low_counts.toarray().flatten()
        
        # Create DataFrame for low-scoring words and counts
        low_df = pd.DataFrame({'Word': low_common_words, 'Frequency': low_word_count})
        low_df = low_df.sort_values(by='Frequency', ascending=False)

        # Plot
        plt.figure(figsize=(10, 6))
        plt.barh(low_df['Word'], low_df['Frequency'], color='salmon')
        plt.xlabel('Frequency')
        plt.title('Top Words in Low-Scoring Reviews')
        plt.gca().invert_yaxis()  # Invert to show the most frequent word at the top
        plt.show()
    else:
        print("No significant words in low-scoring reviews after removing stop words.")
# Out:
# Reading with reviews-ubisoft/reviews_2290180.csv
# <style type="text/css">
# #T_ebe13 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_ebe13 table {
#   border: 1px solid black;
# }
# #T_ebe13_row0_col0, #T_ebe13_row1_col0, #T_ebe13_row2_col0, #T_ebe13_row3_col0, #T_ebe13_row4_col0, #T_ebe13_row5_col0, #T_ebe13_row6_col0, #T_ebe13_row7_col0, #T_ebe13_row8_col0, #T_ebe13_row9_col0 {
#   text-align: left;
# }
# #T_ebe13_row0_col1, #T_ebe13_row9_col1 {
#   background-color: #004a1e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row0_col2 {
#   background-color: #d5efcf;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row0_col3, #T_ebe13_row2_col3, #T_ebe13_row3_col1, #T_ebe13_row4_col2, #T_ebe13_row4_col3, #T_ebe13_row5_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row1_col1 {
#   background-color: #006529;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row1_col2, #T_ebe13_row3_col3, #T_ebe13_row4_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row1_col3, #T_ebe13_row6_col3, #T_ebe13_row7_col3, #T_ebe13_row8_col3, #T_ebe13_row9_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row2_col1 {
#   background-color: #005723;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row2_col2 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row3_col2 {
#   background-color: #edf8e9;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row5_col1 {
#   background-color: #004d1f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row5_col2 {
#   background-color: #b7e2b1;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row6_col1 {
#   background-color: #005221;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row6_col2 {
#   background-color: #90d18d;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row7_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row7_col2 {
#   background-color: #75c477;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row8_col1 {
#   background-color: #005522;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_ebe13_row8_col2 {
#   background-color: #7cc87c;
#   color: #000000;
#   text-align: left;
# }
# #T_ebe13_row9_col2 {
#   background-color: #e0f3db;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_ebe13">
#   <caption>High Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebe13_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_ebe13_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_ebe13_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_ebe13_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebe13_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebe13_row0_col0" class="data row0 col0" >very cool</td>
#       <td id="T_ebe13_row0_col1" class="data row0 col1" >0.961917</td>
#       <td id="T_ebe13_row0_col2" class="data row0 col2" >0.035342</td>
#       <td id="T_ebe13_row0_col3" class="data row0 col3" >0.002741</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ebe13_row1_col0" class="data row1 col0" >nice map</td>
#       <td id="T_ebe13_row1_col1" class="data row1 col1" >0.879866</td>
#       <td id="T_ebe13_row1_col2" class="data row1 col2" >0.111676</td>
#       <td id="T_ebe13_row1_col3" class="data row1 col3" >0.008458</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_ebe13_row2_col0" class="data row2 col0" >i like the mtb and bmx features</td>
#       <td id="T_ebe13_row2_col1" class="data row2 col1" >0.920907</td>
#       <td id="T_ebe13_row2_col2" class="data row2 col2" >0.076689</td>
#       <td id="T_ebe13_row2_col3" class="data row2 col3" >0.002403</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_ebe13_row3_col0" class="data row3 col0" >horrible company that owns it ubitsoft is always constantly ruining such good chances for games</td>
#       <td id="T_ebe13_row3_col1" class="data row3 col1" >0.002872</td>
#       <td id="T_ebe13_row3_col2" class="data row3 col2" >0.023805</td>
#       <td id="T_ebe13_row3_col3" class="data row3 col3" >0.973323</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_ebe13_row4_col0" class="data row4 col0" >game amizing love the sking muintin bikiing to lots of fun</td>
#       <td id="T_ebe13_row4_col1" class="data row4 col1" >0.981217</td>
#       <td id="T_ebe13_row4_col2" class="data row4 col2" >0.016838</td>
#       <td id="T_ebe13_row4_col3" class="data row4 col3" >0.001945</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_ebe13_row5_col0" class="data row5 col0" >best game 10/10</td>
#       <td id="T_ebe13_row5_col1" class="data row5 col1" >0.951273</td>
#       <td id="T_ebe13_row5_col2" class="data row5 col2" >0.045497</td>
#       <td id="T_ebe13_row5_col3" class="data row5 col3" >0.003230</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_ebe13_row6_col0" class="data row6 col0" >Great game</td>
#       <td id="T_ebe13_row6_col1" class="data row6 col1" >0.936125</td>
#       <td id="T_ebe13_row6_col2" class="data row6 col2" >0.056957</td>
#       <td id="T_ebe13_row6_col3" class="data row6 col3" >0.006918</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row7" class="row_heading level0 row7" >19</th>
#       <td id="T_ebe13_row7_col0" class="data row7 col0" >great game</td>
#       <td id="T_ebe13_row7_col1" class="data row7 col1" >0.926472</td>
#       <td id="T_ebe13_row7_col2" class="data row7 col2" >0.063943</td>
#       <td id="T_ebe13_row7_col3" class="data row7 col3" >0.009585</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row8" class="row_heading level0 row8" >20</th>
#       <td id="T_ebe13_row8_col0" class="data row8 col0" >Bro this Game is Smooth ASF. I sold my Lt. Ricksaw from CS2 to buy this game easy money. But nonetheless the game is really comforting and addicting if you dont wanna learn the learning curve just enable auto landing and you can hit insane tricks without the danger of falling</td>
#       <td id="T_ebe13_row8_col1" class="data row8 col1" >0.928281</td>
#       <td id="T_ebe13_row8_col2" class="data row8 col2" >0.062111</td>
#       <td id="T_ebe13_row8_col3" class="data row8 col3" >0.009609</td>
#     </tr>
#     <tr>
#       <th id="T_ebe13_level0_row9" class="row_heading level0 row9" >22</th>
#       <td id="T_ebe13_row9_col0" class="data row9 col0" >some bugs here and there and some micro transactions  but i recommend this game to anyone who likes extreme sports. its harder than you think i will be. just a heads up. i have this on the computer and Playstation would recommend a controller for sure! i would give this 8.5/10 the graphics are stunning and music is pretty great!</td>
#       <td id="T_ebe13_row9_col1" class="data row9 col1" >0.960585</td>
#       <td id="T_ebe13_row9_col2" class="data row9 col2" >0.030562</td>
#       <td id="T_ebe13_row9_col3" class="data row9 col3" >0.008853</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_18c86 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_18c86 table {
#   border: 1px solid black;
# }
# #T_18c86_row0_col0, #T_18c86_row1_col0, #T_18c86_row2_col0, #T_18c86_row3_col0, #T_18c86_row4_col0, #T_18c86_row5_col0, #T_18c86_row6_col0, #T_18c86_row7_col0, #T_18c86_row8_col0, #T_18c86_row9_col0 {
#   text-align: left;
# }
# #T_18c86_row0_col1 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row0_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row0_col3 {
#   background-color: #fee0d2;
#   color: #000000;
#   text-align: left;
# }
# #T_18c86_row1_col1 {
#   background-color: #b71319;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row1_col2 {
#   background-color: #b21218;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row1_col3 {
#   background-color: #b11218;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row2_col1, #T_18c86_row2_col2, #T_18c86_row2_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: left;
# }
# #T_18c86_row3_col1 {
#   background-color: #ed392b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row3_col2 {
#   background-color: #800610;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row3_col3 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row4_col1 {
#   background-color: #f24633;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row4_col2 {
#   background-color: #ac1117;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row4_col3, #T_18c86_row5_col1, #T_18c86_row7_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row5_col2 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row5_col3 {
#   background-color: #fca082;
#   color: #000000;
#   text-align: left;
# }
# #T_18c86_row6_col1 {
#   background-color: #fca98c;
#   color: #000000;
#   text-align: left;
# }
# #T_18c86_row6_col2 {
#   background-color: #71020e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row6_col3 {
#   background-color: #d42121;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row7_col1 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row7_col3 {
#   background-color: #fb7757;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row8_col1 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row8_col2 {
#   background-color: #b61319;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row8_col3 {
#   background-color: #bc141a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row9_col1 {
#   background-color: #c1161b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row9_col2 {
#   background-color: #b51318;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_18c86_row9_col3 {
#   background-color: #940b13;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_18c86">
#   <caption>Low Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18c86_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_18c86_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_18c86_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_18c86_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18c86_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_18c86_row0_col0" class="data row0 col0" >my the crew？？？</td>
#       <td id="T_18c86_row0_col1" class="data row0 col1" >0.147036</td>
#       <td id="T_18c86_row0_col2" class="data row0 col2" >0.831391</td>
#       <td id="T_18c86_row0_col3" class="data row0 col3" >0.021573</td>
#     </tr>
#     <tr>
#       <th id="T_18c86_level0_row1" class="row_heading level0 row1" >28</th>
#       <td id="T_18c86_row1_col0" class="data row1 col0" >Spagheto</td>
#       <td id="T_18c86_row1_col1" class="data row1 col1" >0.162563</td>
#       <td id="T_18c86_row1_col2" class="data row1 col2" >0.694663</td>
#       <td id="T_18c86_row1_col3" class="data row1 col3" >0.142774</td>
#     </tr>
#     <tr>
#       <th id="T_18c86_level0_row2" class="row_heading level0 row2" >47</th>
#       <td id="T_18c86_row2_col0" class="data row2 col0" >### Riders Republic - Review  **Rating:** ★★★★☆ (4/5)  **Introduction:** "Riders Republic" is an expansive outdoor sports game developed by Ubisoft Annecy offering a vibrant open world for players to explore through various extreme sports. Released in 2021 it combines biking snowboarding skiing and wingsuit flying in a lively environment that encourages both competition and exploration. Here’s a detailed look at what makes "Riders Republic" an exciting experience as well as some areas that could be improved.  ---  **Gameplay Mechanics:** - **Variety of Sports:** The game features an impressive range of extreme sports allowing players to switch between biking snowboarding skiing and wingsuit flying seamlessly. Each sport has its own mechanics and style catering to different player preferences. - **Dynamic Open World:** Set in a massive open world that includes iconic national parks like Yosemite and Zion the game encourages exploration. Players can traverse diverse terrains from mountains to valleys with various challenges and events scattered throughout.  ---  **Visuals and Sound Design:** - **Stunning Graphics:** "Riders Republic" boasts vibrant graphics and a colorful art style that brings the outdoor environments to life. The level of detail in the landscapes enhances immersion and showcases the beauty of the different terrains. - **Audio Experience:** The sound design features a lively soundtrack and immersive sound effects with the sounds of nature and sports adding to the overall atmosphere. The commentary during events adds a competitive edge to the experience.  ---  **Multiplayer Experience:** - **Social and Competitive Play:** The game excels in its multiplayer options allowing players to team up or compete against each other in various challenges. The massive multiplayer modes create a lively and dynamic experience with events that can accommodate a large number of players. - **Events and Challenges:** Regular events including time trials and races keep the gameplay fresh. Players can also create and share custom challenges enhancing community engagement.  ---  **Critiques:** - **Learning Curve:** While the controls are generally intuitive mastering the nuances of each sport can take time. New players may find the variety overwhelming initially and a more structured tutorial could help ease the transition. - **Repetitive Challenges:** Some players may find that the challenges can become repetitive over time. More variety in events and game modes could enhance long-term engagement.  ---  **Conclusion:** "Riders Republic" is a thrilling and engaging game that successfully captures the spirit of extreme sports in a beautiful open world. With its variety of sports dynamic multiplayer modes and stunning visuals it offers an exciting experience for both casual gamers and hardcore sports enthusiasts.  If you're looking for a game that allows for exploration competition and a taste of adrenaline-pumping action "Riders Republic" is highly recommended. Its vibrant world and engaging gameplay make it a standout title in the extreme sports genre.  **Overall Recommendation:** A must-try for fans of extreme sports and anyone seeking a fun social gaming experience.</td>
#       <td id="T_18c86_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_18c86_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_18c86_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_18c86_level0_row3" class="row_heading level0 row3" >75</th>
#       <td id="T_18c86_row3_col0" class="data row3 col0" >fun to fall</td>
#       <td id="T_18c86_row3_col1" class="data row3 col1" >0.125632</td>
#       <td id="T_18c86_row3_col2" class="data row3 col2" >0.790346</td>
#       <td id="T_18c86_row3_col3" class="data row3 col3" >0.084022</td>
#     </tr>
# Reading with reviews-ubisoft/reviews_3035570.csv
# <style type="text/css">
# #T_2a153 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_2a153 table {
#   border: 1px solid black;
# }
# #T_2a153_row0_col0, #T_2a153_row1_col0, #T_2a153_row2_col0, #T_2a153_row3_col0, #T_2a153_row4_col0, #T_2a153_row5_col0, #T_2a153_row6_col0, #T_2a153_row7_col0, #T_2a153_row8_col0, #T_2a153_row9_col0 {
#   text-align: left;
# }
# #T_2a153_row0_col1 {
#   background-color: #016e2d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row0_col2 {
#   background-color: #50b264;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row0_col3 {
#   background-color: #f3faf0;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row1_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row1_col2, #T_2a153_row4_col3, #T_2a153_row6_col3, #T_2a153_row8_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row1_col3 {
#   background-color: #0e7936;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row2_col1 {
#   background-color: #005a24;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row2_col2 {
#   background-color: #acdea6;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row2_col3, #T_2a153_row7_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row3_col1 {
#   background-color: #03702e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row3_col2 {
#   background-color: #4aaf61;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row3_col3 {
#   background-color: #f2faef;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row4_col1, #T_2a153_row5_col3, #T_2a153_row6_col1, #T_2a153_row8_col2, #T_2a153_row8_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row4_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row5_col1 {
#   background-color: #006b2b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row5_col2 {
#   background-color: #349d53;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row6_col2 {
#   background-color: #eff9eb;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row7_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row7_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row9_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
#   text-align: left;
# }
# #T_2a153_row9_col2 {
#   background-color: #4db163;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_2a153_row9_col3 {
#   background-color: #006729;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_2a153">
#   <caption>High Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a153_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_2a153_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_2a153_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_2a153_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a153_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a153_row0_col0" class="data row0 col0" >Never really got into the AC games - I only played the first one and black flag for a bit and then moved on hearing a bit about the AC games here and there.  But as someone from the Middle East Mirage drew me in and so far I love it.  Sometimes I just love to walk around and just take in how beautiful the scenery is.  It's also made me love being an Assassin again especially since I feel the player grows their skills alongside Basim.  Additionally the fact you have characters from all walks of life and skin tones makes me feel welcome.  I've only played around 8 hours of the game but this is a game that makes me feel seen heard and welcome in both big and little ways - not many other games have me feel that way.  That being said I'm only judging this game based on a standalone product and not so much a product of the other AC games (since I haven't played them) and or a product of Ubisoft (which I will admit has done some amazing things for this game but I also kinda know about other stuff like Mircotransactions in AC: Odyessy the Glitch es of Star wars outlaws (which kinda enjoyed) very crappy refund policy* the games-as-a-service mindset which I find concerning and makes me hesitant to buy the other AC games.  *you can only refund an game before you've played it... very scummy   Despite that I am very thankful that AC mirage exists. It may not be everyone's cup of tea but the care put into it makes it an instant fav.  This review isn't final and I'll update it as I continue to play. </td>
#       <td id="T_2a153_row0_col1" class="data row0 col1" >0.858113</td>
#       <td id="T_2a153_row0_col2" class="data row0 col2" >0.111673</td>
#       <td id="T_2a153_row0_col3" class="data row0 col3" >0.030214</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_2a153_row1_col0" class="data row1 col0" >its like its trying to mimic the old style of games while trying to be something new but doesnt work out</td>
#       <td id="T_2a153_row1_col1" class="data row1 col1" >0.016738</td>
#       <td id="T_2a153_row1_col2" class="data row1 col2" >0.181798</td>
#       <td id="T_2a153_row1_col3" class="data row1 col3" >0.801463</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_2a153_row2_col0" class="data row2 col0" >Feels like the first Assassins Creed. Looking Forward to completing it So far I found a lot of positives:  - Fair Price (25€ at Steamlaunch) - No XP boost since there is no XP System in the game - Ultrawide Support - Dual Sens Controller Support - Steam Achievements - no woke garbage (so far)</td>
#       <td id="T_2a153_row2_col1" class="data row2 col1" >0.918875</td>
#       <td id="T_2a153_row2_col2" class="data row2 col2" >0.069457</td>
#       <td id="T_2a153_row2_col3" class="data row2 col3" >0.011668</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row3" class="row_heading level0 row3" >12</th>
#       <td id="T_2a153_row3_col0" class="data row3 col0" >Don't listen to the negative reviews. They are just Ubisoft and/or "anti-woke" haters. The game is a GEM. Super fun great graphics and well optimized. I've played mainly on my desktop but also tried a couple of hours on my Steam Deck where it runs great on High settings.  If you've enjoyed AC games in the past then I can't imagine you not LOVING AC Mirage.</td>
#       <td id="T_2a153_row3_col1" class="data row3 col1" >0.848412</td>
#       <td id="T_2a153_row3_col2" class="data row3 col2" >0.114418</td>
#       <td id="T_2a153_row3_col3" class="data row3 col3" >0.037170</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_2a153_row4_col0" class="data row4 col0" >instant refund after 30min dahell is this Ubi ? The worst AC i ever played</td>
#       <td id="T_2a153_row4_col1" class="data row4 col1" >0.002938</td>
#       <td id="T_2a153_row4_col2" class="data row4 col2" >0.024613</td>
#       <td id="T_2a153_row4_col3" class="data row4 col3" >0.972449</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row5" class="row_heading level0 row5" >17</th>
#       <td id="T_2a153_row5_col0" class="data row5 col0" >This is the old school and I would personally recommend.</td>
#       <td id="T_2a153_row5_col1" class="data row5 col1" >0.867559</td>
#       <td id="T_2a153_row5_col2" class="data row5 col2" >0.126814</td>
#       <td id="T_2a153_row5_col3" class="data row5 col3" >0.005628</td>
#     </tr>
#     <tr>
#       <th id="T_2a153_level0_row6" class="row_heading level0 row6" >21</th>
#       <td id="T_2a153_row6_col0" class="data row6 col0" >Worst AC game ever. WORST!</td>
#       <td id="T_2a153_row6_col1" class="data row6 col1" >0.005337</td>
#       <td id="T_2a153_row6_col2" class="data row6 col2" >0.021778</td>
#       <td id="T_2a153_row6_col3" class="data row6 col3" >0.972885</td>
#     </tr>
# <style type="text/css">
# #T_f073c caption {
#   color: black;
#   font-weight: bold;
# }
# #T_f073c table {
#   border: 1px solid black;
# }
# #T_f073c_row0_col0, #T_f073c_row1_col0, #T_f073c_row2_col0, #T_f073c_row3_col0, #T_f073c_row4_col0, #T_f073c_row5_col0, #T_f073c_row6_col0, #T_f073c_row7_col0, #T_f073c_row8_col0, #T_f073c_row9_col0 {
#   text-align: left;
# }
# #T_f073c_row0_col1 {
#   background-color: #fc8e6e;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row0_col2 {
#   background-color: #840711;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row0_col3 {
#   background-color: #f44d38;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row1_col1 {
#   background-color: #fca082;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row1_col2, #T_f073c_row4_col1, #T_f073c_row9_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row1_col3 {
#   background-color: #fcaa8d;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row2_col1, #T_f073c_row2_col2, #T_f073c_row2_col3, #T_f073c_row3_col1, #T_f073c_row3_col2, #T_f073c_row3_col3, #T_f073c_row5_col1, #T_f073c_row5_col2, #T_f073c_row5_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row4_col2 {
#   background-color: #ad1117;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row4_col3 {
#   background-color: #fc9373;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row6_col1 {
#   background-color: #bb141a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row6_col2 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row6_col3, #T_f073c_row8_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row7_col1 {
#   background-color: #af1117;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row7_col2 {
#   background-color: #b31218;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row7_col3 {
#   background-color: #e32f27;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row8_col2 {
#   background-color: #ab1016;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row8_col3 {
#   background-color: #c9181d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_f073c_row9_col1 {
#   background-color: #fc9272;
#   color: #000000;
#   text-align: left;
# }
# #T_f073c_row9_col2 {
#   background-color: #a81016;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_f073c">
#   <caption>Low Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f073c_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_f073c_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_f073c_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_f073c_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f073c_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_f073c_row0_col0" class="data row0 col0" >[h2] Beauty Without Depth [/h2]</td>
#       <td id="T_f073c_row0_col1" class="data row0 col1" >0.074027</td>
#       <td id="T_f073c_row0_col2" class="data row0 col2" >0.834495</td>
#       <td id="T_f073c_row0_col3" class="data row0 col3" >0.091477</td>
#     </tr>
#     <tr>
#       <th id="T_f073c_level0_row1" class="row_heading level0 row1" >18</th>
#       <td id="T_f073c_row1_col0" class="data row1 col0" >Refunded After 11 Mins</td>
#       <td id="T_f073c_row1_col1" class="data row1 col1" >0.063436</td>
#       <td id="T_f073c_row1_col2" class="data row1 col2" >0.888167</td>
#       <td id="T_f073c_row1_col3" class="data row1 col3" >0.048398</td>
#     </tr>
#     <tr>
#       <th id="T_f073c_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_f073c_row2_col0" class="data row2 col0" >Assassin’s Creed Mirage brings the series back to its roots which is great for anyone who loved the older games. Set in 9th-century Baghdad this game feels like a throwback to the classic Assassin's Creed formula focusing more on stealth parkour and assassinations rather than the huge RPG-style worlds from recent entries like Valhalla or Odyssey.  What’s Good: 1. Awesome Setting: Baghdad looks stunning. The city is full of life from busy markets to narrow alleyways and towering buildings. It’s not as big as some of the recent games but it’s packed with detail and really gives you the vibe of the time period.  2. Stealth is Back: If you miss the days of sneaking around and planning the perfect kill Mirage has you covered. It feels like old-school Assassin’s Creed—blend into crowds parkour across rooftops and use the environment to your advantage. The assassinations are a lot of fun to pull off.  3. Focused Story: The game follows Basim (you might remember him from Valhalla) and the story is much more tight and personal. It’s a straightforward engaging plot without the massive bloat of side quests and grindy missions.  4. Simple Progression: Gone are the overwhelming RPG elements. You don’t have to worry about grinding levels or a huge skill tree. The upgrade system is much simpler which makes the game feel more accessible and keeps the focus on the action.  5. Great Atmosphere: The sound music and voice acting all help create an immersive world. Whether you’re running across rooftops or walking through the crowded streets the sound design really pulls you into the experience.  What’s Not So Great: 1. Smaller Scale: If you loved the gigantic open worlds in the last few Assassin’s Creed games this one might feel a bit small. The world is more compact and there aren’t as many side activities to do. That said the tighter focus works well for this kind of game.  2. Combat is Just Okay: While the stealth mechanics are solid the combat isn’t very deep. It gets the job done but it doesn’t have the complexity or challenge of some other action games. If you prefer fighting over sneaking you might find the combat a bit repetitive.  3. Minor Bugs: There are a few bugs and technical issues like frame drops in busy areas or the occasional visual glitch. Nothing too serious but it can be a bit distracting at times.  4. Not Much New: Mirage is more of a return to basics than a game that introduces a lot of new stuff. It plays it safe so if you’re looking for fresh ideas or big changes to the series you might not find them here.  Should You Play It? If you’ve been missing the older style of Assassin’s Creed Mirage will feel like a breath of fresh air. It’s a shorter more focused game that brings back the stealth and parkour we loved from the early days. However if you prefer the giant open-world RPGs of recent games this one might feel a bit too stripped down.  Overall it’s a solid return to form but it’s not going to blow your mind with innovation. It’s great for a more focused old-school assassin experience.  Rating: 8/10</td>
#       <td id="T_f073c_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f073c_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_f073c_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f073c_level0_row3" class="row_heading level0 row3" >31</th>
#       <td id="T_f073c_row3_col0" class="data row3 col0" >It's the same slop they always sell ad infinitum. If you're like me a person hasn't enjoyed a Ubislop game since Far Cry 3 and the original ACs then this "return to form" isn't going to change your opinion.  It's so painfully obvious that Ubislop REALLY has absolutely no faith whatsoever in the intelligence of the player. Everything from the UI to the gameplay treats you like an idiot. Seeing as how people STILL BUY these garbage games every year...they're actually probably not far off in regards to their fan boys. Ubislop will never learn they will never again innovate and it's because of you idiots who keep buying this crap. Why should they contribute any innovations whatsoever to the industry when idiots like to be spoon fed the same formulaic slop year after year after year?  It's become so bad that they greedily turned this DLC for Valhalla int
# Reading with reviews-ubisoft/reviews_220240.csv
# <style type="text/css">
# #T_00517 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_00517 table {
#   border: 1px solid black;
# }
# #T_00517_row0_col0, #T_00517_row1_col0, #T_00517_row2_col0, #T_00517_row3_col0, #T_00517_row4_col0, #T_00517_row5_col0, #T_00517_row6_col0, #T_00517_row7_col0, #T_00517_row8_col0, #T_00517_row9_col0 {
#   text-align: left;
# }
# #T_00517_row0_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row0_col2, #T_00517_row1_col1, #T_00517_row4_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row0_col3 {
#   background-color: #026f2e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row1_col2, #T_00517_row3_col3 {
#   background-color: #f3faf0;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row1_col3, #T_00517_row2_col3, #T_00517_row4_col1, #T_00517_row4_col2, #T_00517_row5_col1, #T_00517_row6_col3, #T_00517_row7_col1, #T_00517_row8_col3, #T_00517_row9_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row2_col1 {
#   background-color: #004a1e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row2_col2 {
#   background-color: #cdecc7;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row3_col1 {
#   background-color: #006227;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row3_col2 {
#   background-color: #58b668;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row5_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row5_col3 {
#   background-color: #00481d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row6_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row6_col2 {
#   background-color: #005221;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row7_col2 {
#   background-color: #cbebc5;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row7_col3 {
#   background-color: #004d1f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row8_col1 {
#   background-color: #00491d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row8_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
#   text-align: left;
# }
# #T_00517_row9_col1 {
#   background-color: #004c1e;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_00517_row9_col2 {
#   background-color: #ccebc6;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_00517">
#   <caption>High Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00517_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_00517_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_00517_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_00517_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00517_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00517_row0_col0" class="data row0 col0" >fat cry pee</td>
#       <td id="T_00517_row0_col1" class="data row0 col1" >0.020266</td>
#       <td id="T_00517_row0_col2" class="data row0 col2" >0.132127</td>
#       <td id="T_00517_row0_col3" class="data row0 col3" >0.847607</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_00517_row1_col0" class="data row1 col0" >Awesome game!</td>
#       <td id="T_00517_row1_col1" class="data row1 col1" >0.977423</td>
#       <td id="T_00517_row1_col2" class="data row1 col2" >0.019634</td>
#       <td id="T_00517_row1_col3" class="data row1 col3" >0.002942</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row2" class="row_heading level0 row2" >98</th>
#       <td id="T_00517_row2_col0" class="data row2 col0" >This game is mostly recommended</td>
#       <td id="T_00517_row2_col1" class="data row2 col1" >0.955808</td>
#       <td id="T_00517_row2_col2" class="data row2 col2" >0.042320</td>
#       <td id="T_00517_row2_col3" class="data row2 col3" >0.001872</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row3" class="row_heading level0 row3" >99</th>
#       <td id="T_00517_row3_col0" class="data row3 col0" >Probably the best far cry. Amazing story and gameplay .The tattoo skill thing is also very unique just one downside idk why it's laggy for me and idk why cuz I played red dead 2 on ultra and I had like 100 fps. 8/10</td>
#       <td id="T_00517_row3_col1" class="data row3 col1" >0.887939</td>
#       <td id="T_00517_row3_col2" class="data row3 col2" >0.081968</td>
#       <td id="T_00517_row3_col3" class="data row3 col3" >0.030093</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row4" class="row_heading level0 row4" >101</th>
#       <td id="T_00517_row4_col0" class="data row4 col0" >good luck logging in 90% of the time. Fuck you stupid mfers at ubisoft why does a 12 y/o game with no multiplayer require a log in you mother fuckers.</td>
#       <td id="T_00517_row4_col1" class="data row4 col1" >0.002624</td>
#       <td id="T_00517_row4_col2" class="data row4 col2" >0.016425</td>
#       <td id="T_00517_row4_col3" class="data row4 col3" >0.980952</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row5" class="row_heading level0 row5" >104</th>
#       <td id="T_00517_row5_col0" class="data row5 col0" >Shove your piece of shitty launcher deep in your arse and fuck off.</td>
#       <td id="T_00517_row5_col1" class="data row5 col1" >0.004563</td>
#       <td id="T_00517_row5_col2" class="data row5 col2" >0.027435</td>
#       <td id="T_00517_row5_col3" class="data row5 col3" >0.968002</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row6" class="row_heading level0 row6" >112</th>
#       <td id="T_00517_row6_col0" class="data row6 col0" >nice throw back game</td>
#       <td id="T_00517_row6_col1" class="data row6 col1" >0.867550</td>
#       <td id="T_00517_row6_col2" class="data row6 col2" >0.126793</td>
#       <td id="T_00517_row6_col3" class="data row6 col3" >0.005657</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row7" class="row_heading level0 row7" >114</th>
#       <td id="T_00517_row7_col0" class="data row7 col0" >Ubisoft has made this game literally unplayable for me with no option to link to my Steam account. There is also effectively no way to get in contact with support.</td>
#       <td id="T_00517_row7_col1" class="data row7 col1" >0.004457</td>
#       <td id="T_00517_row7_col2" class="data row7 col2" >0.043121</td>
#       <td id="T_00517_row7_col3" class="data row7 col3" >0.952422</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row8" class="row_heading level0 row8" >122</th>
#       <td id="T_00517_row8_col0" class="data row8 col0" >Great game come back every few moths to replay</td>
#       <td id="T_00517_row8_col1" class="data row8 col1" >0.959194</td>
#       <td id="T_00517_row8_col2" class="data row8 col2" >0.037373</td>
#       <td id="T_00517_row8_col3" class="data row8 col3" >0.003433</td>
#     </tr>
#     <tr>
#       <th id="T_00517_level0_row9" class="row_heading level0 row9" >123</th>
#       <td id="T_00517_row9_col0" class="data row9 col0" >Very good</td>
#       <td id="T_00517_row9_col1" class="data row9 col1" >0.951874</td>
#       <td id="T_00517_row9_col2" class="data row9 col2" >0.042852</td>
#       <td id="T_00517_row9_col3" class="data row9 col3" >0.005274</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cbadd caption {
#   color: black;
#   font-weight: bold;
# }
# #T_cbadd table {
#   border: 1px solid black;
# }
# #T_cbadd_row0_col0, #T_cbadd_row1_col0, #T_cbadd_row2_col0, #T_cbadd_row3_col0, #T_cbadd_row4_col0, #T_cbadd_row5_col0, #T_cbadd_row6_col0, #T_cbadd_row7_col0, #T_cbadd_row8_col0, #T_cbadd_row9_col0 {
#   text-align: left;
# }
# #T_cbadd_row0_col1, #T_cbadd_row0_col2, #T_cbadd_row0_col3, #T_cbadd_row2_col1, #T_cbadd_row2_col2, #T_cbadd_row2_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: left;
# }
# #T_cbadd_row1_col1 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row1_col2, #T_cbadd_row3_col3, #T_cbadd_row7_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row1_col3 {
#   background-color: #ffeee6;
#   color: #000000;
#   text-align: left;
# }
# #T_cbadd_row3_col1, #T_cbadd_row4_col2 {
#   background-color: #ca181d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row3_col2 {
#   background-color: #c1161b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row4_col1 {
#   background-color: #77040f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row4_col3 {
#   background-color: #73030f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row5_col1 {
#   background-color: #fb7656;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row5_col2 {
#   background-color: #75030f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row5_col3, #T_cbadd_row7_col3 {
#   background-color: #fca082;
#   color: #000000;
#   text-align: left;
# }
# #T_cbadd_row6_col1 {
#   background-color: #af1117;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row6_col2 {
#   background-color: #aa1016;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row6_col3 {
#   background-color: #f5533b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row7_col2 {
#   background-color: #a30f15;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row8_col1 {
#   background-color: #f44f39;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row8_col2 {
#   background-color: #b11218;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row8_col3 {
#   background-color: #8e0912;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row9_col1 {
#   background-color: #fc9c7d;
#   color: #000000;
#   text-align: left;
# }
# #T_cbadd_row9_col2 {
#   background-color: #840711;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_cbadd_row9_col3 {
#   background-color: #f34a36;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_cbadd">
#   <caption>Low Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbadd_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_cbadd_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_cbadd_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_cbadd_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbadd_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cbadd_row0_col0" class="data row0 col0" >I am really surprised I didn't review this game before.  Far Cry 3 was one of the first games I picked up after taking a long break from gaming during my time pursuing a PhD in New Zealand and Australia. A colleague had been raving about it so I decided to give it a try—and it immediately pulled me in. The tropical Rook Islands with their lush landscapes and vibrant cultures felt oddly familiar reflecting much of the environment and atmosphere I had grown accustomed to in the Pacific. That familiarity made the game's immersive world even more engaging blurring the line between fantasy and reality in a way I hadn't experienced in years.  Set in an exotic paradise turned hostile Far Cry 3 blends the thrill of 1980s action-adventure films with the complexity of role-playing elements. Its lush dangerous ecosystem—complete with unpredictable wildlife vast jungles and hidden dangers—feels alive making exploration both rewarding and fraught with tension. What makes this setting even more engaging is its resemblance to certain parts of the Pacific and that familiarity made the story hit closer to home. The Rakyat tribe’s fight to preserve their land from outsiders echoes real-world struggles of indigenous peoples dealing with exploitation under neoliberal and late-stage capitalism. This narrative thread gave the game a resonance that went beyond mere escapism.  The game’s cast of outlandish yet disturbingly relatable characters only heightens the atmosphere. Vaas the game’s iconic antagonist is both unhinged and charismatic embodying the chaos of the islands themselves. His madness makes the story unpredictable and kept me glued to every encounter. While Far Cry 3 leans into the bombastic over-the-top action of classic adventure films it still manages to address deeper more introspective themes. The world feels like a paradise on the surface but hides a darker undercurrent of violence and greed a metaphor that felt even more pointed given the familiarity of the setting during my time in the Pacific.  The Rook Islands aren’t just a backdrop—they are a character in their own right. Their beauty is a double-edged sword masking the ever-present danger that lies in wait around every corner. As someone coming back to gaming after years away Far Cry 3 offered a perfect mix of escapism and grounded reflection. Its open-world design combined with a narrative that subtly grapples with exploitation and resistance made it stand out. For me this game wasn’t just an adventure—it was a reminder of the world I was living in but framed through a different lens.  If you’re looking for a game that blends explosive action with deeper cultural and environmental undertones Far Cry 3 is a masterclass in balancing the two. Returning to gaming after years away it was exactly what I needed—a perfect bridge between escapism and reality.</td>
#       <td id="T_cbadd_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_cbadd_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_cbadd_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cbadd_level0_row1" class="row_heading level0 row1" >97</th>
#       <td id="T_cbadd_row1_col0" class="data row1 col0" >Alice in wonderland ft. Silenced MP5 and Nacho from BCS</td>
#       <td id="T_cbadd_row1_col1" class="data row1 col1" >0.098239</td>
#       <td id="T_cbadd_row1_col2" class="data row1 col2" >0.893745</td>
#       <td id="T_cbadd_row1_col3" class="data row1 col3" >0.008016</td>
#     </tr>
#     <tr>
#       <th id="T_cbadd_level0_row2" class="row_heading level0 row2" >107</th>
#       <td id="T_cbadd_row2_col0" class="data row2 col0" >Dogshit Ubisoft being garbage. Burn you trash company you deserve to disappear into nothingness.  First disable Ubisoft's unable-to-normally-turn-off spy-on-you-while-you-play bullshit software. To do this..  1. Type '%appdata%' into windows search and hit enter go back a page and go into 'Local' then into 'Ubishit Game Launcher' folder open 'settings.yaml' with Notepad or if you're a high-tier individual use Notepad++. 2. Scroll down or CTRL+F and find 'masters'. 3. In the quotation marks of 'password' and 'username' put a space in between for both. 4. Scroll down or CTRL+F and find 'user'. 5. Find 'offline' and change it from 'false' to 'true'. 6. Save and close file. 7. Right click 'settings.yaml' and set to 'Read-only' so ppsoft can't change the settings.  Done Ubidogshit will still launch but will not connect to the internet so at least it's benign.  Second for the game to even be launchable..  1. Set cpu affinity on the game to only use PHYSICAL cores. Disable hyperthreading. Use Process Lasso. 2. Put '-skipintro -affinity 4294967295' into the steam launch options. '-skipintro' will skip the cringe logos that are normally unskippable when you launch the game and '-affinity 4294967295' does some 32-bit cpu bullshit so the game can actually launch and not eat shit. 3. Laun
# Reading with reviews-ubisoft/reviews_33230.csv
# <style type="text/css">
# #T_7ddfe caption {
#   color: black;
#   font-weight: bold;
# }
# #T_7ddfe table {
#   border: 1px solid black;
# }
# #T_7ddfe_row0_col0, #T_7ddfe_row1_col0, #T_7ddfe_row2_col0, #T_7ddfe_row3_col0, #T_7ddfe_row4_col0, #T_7ddfe_row5_col0, #T_7ddfe_row6_col0, #T_7ddfe_row7_col0, #T_7ddfe_row8_col0, #T_7ddfe_row9_col0 {
#   text-align: left;
# }
# #T_7ddfe_row0_col1, #T_7ddfe_row3_col3, #T_7ddfe_row4_col3, #T_7ddfe_row6_col2, #T_7ddfe_row6_col3, #T_7ddfe_row7_col1, #T_7ddfe_row9_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: left;
# }
# #T_7ddfe_row0_col2 {
#   background-color: #e1f3dc;
#   color: #000000;
#   text-align: left;
# }
# #T_7ddfe_row0_col3, #T_7ddfe_row2_col2, #T_7ddfe_row6_col1, #T_7ddfe_row7_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_7ddfe_row1_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_7ddfe_row1_col2 {
#   background-color: #6bc072;
#   color: #000000;
#   text-align: left;
# }
# #T_7ddfe_row1_col3 {
#   background-color: #f3faf0;
#   color: #000000;
#   text-align: left;
# }
# #T_7ddfe_row2_col1 {
#   background-color: #0e7936;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_7ddfe_row2_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
#   text-align: left;
# }
# #T_7ddfe_row3_col1 {
#   background-color: #00451c;
# ...
# Reading with reviews-ubisoft/reviews_2379390.csv
# <style type="text/css">
# #T_fc9d2 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_fc9d2 table {
#   border: 1px solid black;
# }
# #T_fc9d2_row0_col0, #T_fc9d2_row1_col0, #T_fc9d2_row2_col0, #T_fc9d2_row3_col0, #T_fc9d2_row4_col0, #T_fc9d2_row5_col0, #T_fc9d2_row6_col0, #T_fc9d2_row7_col0, #T_fc9d2_row8_col0, #T_fc9d2_row9_col0 {
#   text-align: left;
# }
# #T_fc9d2_row0_col1, #T_fc9d2_row1_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row0_col2 {
#   background-color: #b8e3b2;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row0_col3, #T_fc9d2_row2_col2, #T_fc9d2_row2_col3, #T_fc9d2_row3_col1, #T_fc9d2_row4_col1, #T_fc9d2_row8_col1, #T_fc9d2_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row1_col2 {
#   background-color: #c4e8bd;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row1_col3, #T_fc9d2_row5_col3, #T_fc9d2_row6_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row2_col1, #T_fc9d2_row3_col3, #T_fc9d2_row7_col2, #T_fc9d2_row9_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row3_col2 {
#   background-color: #d3eecd;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row4_col2 {
#   background-color: #c6e8bf;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row4_col3, #T_fc9d2_row8_col3 {
#   background-color: #00471c;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row5_col1 {
#   background-color: #005723;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row5_col2 {
#   background-color: #7fc97f;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row6_col1 {
#   background-color: #00491d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row6_col2 {
#   background-color: #e4f5df;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row7_col1 {
#   background-color: #006d2c;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_fc9d2_row7_col3 {
#   background-color: #f5fbf3;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row8_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
#   text-align: left;
# }
# #T_fc9d2_row9_col2 {
#   background-color: #d5efcf;
#   color: #000000;
#   text-align: left;
# }
# </style>
# <table id="T_fc9d2">
#   <caption>High Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc9d2_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_fc9d2_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_fc9d2_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_fc9d2_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc9d2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_fc9d2_row0_col0" class="data row0 col0" >The sci-fi concept is good. The verity of operators are good in order to combat and win the various objects. Once you learn how to approach the different situations in order to minimize and defeat the onslaught of Archeans it becomes a worthwhile game and challenge.</td>
#       <td id="T_fc9d2_row0_col1" class="data row0 col1" >0.948036</td>
#       <td id="T_fc9d2_row0_col2" class="data row0 col2" >0.047854</td>
#       <td id="T_fc9d2_row0_col3" class="data row0 col3" >0.004110</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_fc9d2_row1_col0" class="data row1 col0" >This is actually a good game but not for this price(they do not update it anymore). But I enjoyed the experience</td>
#       <td id="T_fc9d2_row1_col1" class="data row1 col1" >0.947238</td>
#       <td id="T_fc9d2_row1_col2" class="data row1 col2" >0.043637</td>
#       <td id="T_fc9d2_row1_col3" class="data row1 col3" >0.009125</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_fc9d2_row2_col0" class="data row2 col0" >The game is tons of fun to pass the time. Seriously recommend to anyone looking to play a game to pass the time</td>
#       <td id="T_fc9d2_row2_col1" class="data row2 col1" >0.983779</td>
#       <td id="T_fc9d2_row2_col2" class="data row2 col2" >0.014449</td>
#       <td id="T_fc9d2_row2_col3" class="data row2 col3" >0.001771</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_fc9d2_row3_col0" class="data row3 col0" >honestly dont waste your money terrible game for the franchise played 39 mins over 2 sessions couldnt get into it clunky and a real down turn for the franchise</td>
#       <td id="T_fc9d2_row3_col1" class="data row3 col1" >0.003832</td>
#       <td id="T_fc9d2_row3_col2" class="data row3 col2" >0.036817</td>
#       <td id="T_fc9d2_row3_col3" class="data row3 col3" >0.959351</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_fc9d2_row4_col0" class="data row4 col0" >this game was disappointing. should have bin a dlc for r6 seige</td>
#       <td id="T_fc9d2_row4_col1" class="data row4 col1" >0.004921</td>
#       <td id="T_fc9d2_row4_col2" class="data row4 col2" >0.043257</td>
#       <td id="T_fc9d2_row4_col3" class="data row4 col3" >0.951821</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row5" class="row_heading level0 row5" >13</th>
#       <td id="T_fc9d2_row5_col0" class="data row5 col0" >a lot of fun</td>
#       <td id="T_fc9d2_row5_col1" class="data row5 col1" >0.925992</td>
#       <td id="T_fc9d2_row5_col2" class="data row5 col2" >0.067164</td>
#       <td id="T_fc9d2_row5_col3" class="data row5 col3" >0.006844</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_fc9d2_row6_col0" class="data row6 col0" >pretty fun. should be cheaper since they dont update anymore. good game to crack some cold ones with the boys and play</td>
#       <td id="T_fc9d2_row6_col1" class="data row6 col1" >0.965406</td>
#       <td id="T_fc9d2_row6_col2" class="data row6 col2" >0.028983</td>
#       <td id="T_fc9d2_row6_col3" class="data row6 col3" >0.005612</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row7" class="row_heading level0 row7" >19</th>
#       <td id="T_fc9d2_row7_col0" class="data row7 col0" >i like it</td>
#       <td id="T_fc9d2_row7_col1" class="data row7 col1" >0.859746</td>
#       <td id="T_fc9d2_row7_col2" class="data row7 col2" >0.126362</td>
#       <td id="T_fc9d2_row7_col3" class="data row7 col3" >0.013893</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_fc9d2_row8_col0" class="data row8 col0" >Leaver penalty should not be applied when you are already dead and literally cannot play the rest of the round.</td>
#       <td id="T_fc9d2_row8_col1" class="data row8 col1" >0.002592</td>
#       <td id="T_fc9d2_row8_col2" class="data row8 col2" >0.047043</td>
#       <td id="T_fc9d2_row8_col3" class="data row8 col3" >0.950365</td>
#     </tr>
#     <tr>
#       <th id="T_fc9d2_level0_row9" class="row_heading level0 row9" >22</th>
#       <td id="T_fc9d2_row9_col0" class="data row9 col0" >Biggest single piece of dogwater. It does not offer a lot for a pricey game.  Its basically a reskin of r6 with a different mode. This game is already dead. 3/10</td>
#       <td id="T_fc9d2_row9_col1" class="data row9 col1" >0.004693</td>
#       <td id="T_fc9d2_row9_col2" class="data row9 col2" >0.036085</td>
#       <td id="T_fc9d2_row9_col3" class="data row9 col3" >0.959222</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_73809 caption {
#   color: black;
#   font-weight: bold;
# }
# #T_73809 table {
#   border: 1px solid black;
# }
# #T_73809_row0_col0, #T_73809_row1_col0, #T_73809_row2_col0, #T_73809_row3_col0, #T_73809_row4_col0, #T_73809_row5_col0, #T_73809_row6_col0, #T_73809_row7_col0, #T_73809_row8_col0, #T_73809_row9_col0 {
#   text-align: left;
# }
# #T_73809_row0_col1, #T_73809_row0_col2, #T_73809_row0_col3, #T_73809_row1_col1, #T_73809_row1_col2, #T_73809_row1_col3, #T_73809_row3_col1, #T_73809_row3_col2, #T_73809_row3_col3, #T_73809_row6_col1, #T_73809_row6_col2, #T_73809_row6_col3 {
#   background-color: #fff5f0;
#   color: #000000;
#   text-align: left;
# }
# #T_73809_row2_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row2_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row2_col3 {
#   background-color: #fcaf93;
#   color: #000000;
#   text-align: left;
# }
# #T_73809_row4_col1 {
#   background-color: #fdc5ae;
#   color: #000000;
#   text-align: left;
# }
# #T_73809_row4_col2 {
#   background-color: #920a13;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row4_col3 {
#   background-color: #75030f;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row5_col1, #T_73809_row7_col2, #T_73809_row8_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row5_col2, #T_73809_row9_col3 {
#   background-color: #c9181d;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row5_col3 {
#   background-color: #800610;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row7_col1 {
#   background-color: #fc8666;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row7_col3 {
#   background-color: #fc8a6a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row8_col1 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row8_col2 {
#   background-color: #bf151b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row9_col1 {
#   background-color: #bb141a;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_73809_row9_col2 {
#   background-color: #af1117;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_73809">
#   <caption>Low Scoring Reviews</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73809_level0_col0" class="col_heading level0 col0" >review</th>
#       <th id="T_73809_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_73809_level0_col2" class="col_heading level0 col2" >neutral</th>
#       <th id="T_73809_level0_col3" class="col_heading level0 col3" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73809_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_73809_row0_col0" class="data row0 col0" >⠄⠄⠄⠄⠄⣀⣶⣾⣿⣦⡔⣶⣶⣶⣶⣶⣶⣶⣶⣶⣶⣶⣶⢢⣴⣿⣷⣶⣄ ⠄⠄⠄⠄⣰⣿⣿⠿⢿⣧⣸⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⣇⣼⡿⠉⢿⣿⡆⠄ ⠄⠄⠄⢰⣿⠟⠻⣀⠜⠛⣿⡾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢧⠟⠛⣷⣶⡿⠛⢿⡆⠄ ⠄⠄⠄⣿⣿⣶⣶⠉⢲⣶⢟⣽⣮⣭⣭⣭⣭⣭⣭⣭⣭⣵⣯⡳⣶⡿⠛⢿⣦⣾⣿⠄ ⠄⠄⢸⣿⣿⣿⣿⣿⣿⢣⡟⠁⠄⠙⣿⣿⣿⣿⣿⣿⠋⠄⠈⢻⡜⣧⣤⣾⣿⣿⣿⡇⠄ ⠄⠄⣼⣿⣿⣿⣿⡿⣵⣿⣧⣀⣀⣠⣿⣿⣿⣿⣿⣿⣄⣀⣀⣼⣿⣮⢿⣿⣿⣿⣿⣧⠄ ⠄⠄⣿⣿⣿⣿⡿⣽⣿⡟⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⠛⢻⣿⣯⢿⣿⣿⣿⣿⠄ ⠄⠄⣿⣿⣿⣿⢳⣿⠋⠄⠄⠄⠄⠄⠄⠄𝓝𝓲𝓬𝓮 ⠄⠄⠄⠄⠄⠙⣿⡞⣿⣿⣿⣿⠄ ⠄⠄⢻⣿⣿⣇⣿⠇⠄⠄⠄⠄⠄⠄⠄𝓖𝓪𝓶𝓮⠄⠄⠄⠄⠄⠄⠄⠸⣿⣸⣿⣿⡟⠄‎ ⠄⠄⠈⠿⠿⣼⡟⠄⠄⠄⠄⠄⠄⠄⠄金賀勝⠄⠄⠄⠄⠄⠄ ⠄⠄⢻⣧⠻⠿⠁</td>
#       <td id="T_73809_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_73809_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_73809_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73809_level0_row1" class="row_heading level0 row1" >71</th>
#       <td id="T_73809_row1_col0" class="data row1 col0" >Это позор. Эта игра не стоит даже тех 300 рублей которые за нее просят на распродаже. За все время которое эта игра существовала разработчики не сделали буквально ничего чтобы игра не ощущалась как кусок сиджа который вырвали из него просто чтобы вырвать.  Чтобы понять масштаб проблемы достаточно взглянуть на основной геймплейный контент который данная игра предоставляет - оперативники. Все оперативники что есть в игре - те же оперативники которых мы по сей день видим в сидже в игре изначально не было заявлено а в следствии и не было сделано НИ ОДНОГО НОВОГО УНИКАЛЬНОГО СОЛДАТИКА. Все оперативники - по сути те же самые оружие у них - то же самое что и в сидже. Доходит до глупого что в PvE шутере косящем под L4D и GTFO разом отдача напрямую взята из PvP шутера из-за чего нормально пострелять по ордам пришельцев банально не выходит.  У игры нет никакого стиля у игры нет лица. Противники выглядят невероятно вторично дизайн крайне уныл и безвкусен. Как можно было настолько испортить и без того не слишком то оригинальные дизайны времен Аутбрейка?  Про постановку оригинальный сюжетный контент и прочее уже и говорить не обязательно. Ничего из этого в игре никогда не было.  Суммарное впечатление осталось хуже некуда. У игры всего один плюс - она выглядит покрасивее сиджа жаль что это больше проблема испорченной графики сиджа нежели достижение разработчиков зомби-режима который должен был остаться в сидже.</td>
#       <td id="T_73809_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_73809_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_73809_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73809_level0_row2" class="row_heading level0 row2" >96</th>
#       <td id="T_73809_row2_col0" class="data row2 col0" >Optimizing shaders .......for 20 min....</td>
#       <td id="T_73809_row2_col1" class="data row2 col1" >0.100038</td>
#       <td id="T_73809_row2_col2" class="data row2 col2" >0.845433</td>
#       <td id="T_73809_row2_col3" class="data row2 col3" >0.054529</td>
#     </tr>
#     <tr>
#       <th id="T_73809_level0_row3" class="row_heading level0 row3" >135</th>
#       <td id="T_73809_row3_col0" class="data row3 col0" >Ugh how much I wish I could recommend this.  It actually has a really awesome approach to mixed stealth and action gameplay with soft-failure (in most cases) and the ability to regain stealth after partial failures.  Combat itself is very smooth.  Fun gameplay loop.  This thing definitely had potential.  Too bad I don't have more time for positive stuff though.  Here's what you really need to know: the game is abandoned but they still want $40 and they have an upsell from there?  and in-game DLC from there?  Jeesums.  It only has 20 of the currently 71 operators in Siege with no plans to add more.  They do very minor in-game events rather than doing any meaningful content development for it.  The biggest issue is the maps...  the rotation of maps will get stale pretty fast.  The game's endgame modes are weekly rotating endless missions and events that rotate on a longer timeframe.  This would be mediocre enough but at least keep some variety going for long-time players if it were possible to actually play them.  Both endgame modes *require* a full 3-person party and since the game is as dead as Drake's street cred you can just wait hours in matchmaking and never be allowed to play the game.  Short of those endgame-ish features which would be modest but somewhat fun if they were available but they really aren't...  the game's main progression is essentially to get a series of achievements on each set of levels.  For the most part it's pretty fun but some of those achievements are unreasonably hard and become sticking points particularly ones involving specific rare variants of enemies.  Sometimes you're required to do weirdly specific things to weirdly uncommon archaean and if you play on a public group your random buddies might just kill it before you get to it anyways.  And then once you complete that progression tree there's suddenly...  not really much you can advance besides level up all your operators if you haven't already.  Also the high tier zone 3 mission (which is the final zone in any incursion) that shows up in higher difficulty levels is a cheesy ass boss fight against a super tanky hypermobile enemy.  The fight makes for an incredibly disappointing unwanted crescendo where you were playing an honestly well-designed stealth game but it culminates in a loud messy fight where stealth is meaningless.  Worse if your build was optimized for
